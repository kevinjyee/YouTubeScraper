# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob

# %%
# - iterate over tensorflow record, one example at a time
num_bad_labels = 0
num_videos_in_record = 0

import glob
filenames = glob.glob('data/*.tfrecord')
featureDict = {}
for video_level_data in filenames:
    print('processing ',video_level_data)
    
    num_videos_in_part = 0
    for example in tf.python_io.tf_record_iterator(video_level_data):
        num_videos_in_record += 1
        num_videos_in_part += 1
        # yield example
        tf_example = tf.train.Example.FromString(example)

        # get video id from example
        vid_id = tf_example.features.feature['video_id'].bytes_list.value[0].decode(encoding='UTF-8')
        
        # get list of labels from example
        label_idx_list = tf_example.features.feature["labels"].int64_list.value

        # instantiate list for KEY=vid_id
        featureDict[vid_id] = label_idx_list
   

    print('############# {} VIDEOS IN RECORD ##############'.format(num_videos_in_part))                    
print('\nAnalyzed {} videos from YT8M'.format(num_videos_in_record))
# Out:
# processing  data\train0_.tfrecord
# ############# 1230 VIDEOS IN RECORD ##############
# processing  data\train19.tfrecord
# ############# 1236 VIDEOS IN RECORD ##############
# processing  data\train45.tfrecord
# ############# 1187 VIDEOS IN RECORD ##############
# processing  data\train4B.tfrecord
# ############# 1233 VIDEOS IN RECORD ##############
# processing  data\train4f.tfrecord
# ############# 1226 VIDEOS IN RECORD ##############
# processing  data\train4V.tfrecord
# ############# 1154 VIDEOS IN RECORD ##############
# processing  data\train5A.tfrecord
# ############# 1181 VIDEOS IN RECORD ##############
# processing  data\train5r.tfrecord
# ############# 1286 VIDEOS IN RECORD ##############
# processing  data\train6A.tfrecord
# ############# 1142 VIDEOS IN RECORD ##############
# processing  data\train6l.tfrecord
# ############# 1204 VIDEOS IN RECORD ##############
# processing  data\train6y.tfrecord
# ############# 1195 VIDEOS IN RECORD ##############
# processing  data\train7S.tfrecord
# ############# 1281 VIDEOS IN RECORD ##############
# processing  data\train8D.tfrecord
# ############# 1144 VIDEOS IN RECORD ##############
# processing  data\train99.tfrecord
# ############# 1203 VIDEOS IN RECORD ##############
# processing  data\train9o.tfrecord
# ############# 1242 VIDEOS IN RECORD ##############
# processing  data\trainae.tfrecord
# ############# 1189 VIDEOS IN RECORD ##############
# processing  data\trainAI.tfrecord
# ############# 1246 VIDEOS IN RECORD ##############
# processing  data\trainAp.tfrecord
# ############# 1264 VIDEOS IN RECORD ##############
# processing  data\trainbF.tfrecord
# ############# 1217 VIDEOS IN RECORD ##############
# processing  data\trainBu.tfrecord
# ############# 1216 VIDEOS IN RECORD ##############
# processing  data\trainbU.tfrecord
# ############# 1216 VIDEOS IN RECORD ##############
# processing  data\trainbX.tfrecord
# ############# 1180 VIDEOS IN RECORD ##############
# processing  data\trainCj.tfrecord
# ############# 1265 VIDEOS IN RECORD ##############
# processing  data\trainc_.tfrecord
# ############# 1221 VIDEOS IN RECORD ##############
# processing  data\trainDh.tfrecord
# ############# 1197 VIDEOS IN RECORD ##############
# processing  data\traindw.tfrecord
# ############# 1158 VIDEOS IN RECORD ##############
# processing  data\traineA.tfrecord
# ############# 1144 VIDEOS IN RECORD ##############
# processing  data\traineC.tfrecord
# ############# 1204 VIDEOS IN RECORD ##############
# processing  data\trainEe.tfrecord
# ############# 1163 VIDEOS IN RECORD ##############
# processing  data\trainfQ.tfrecord
# ############# 1278 VIDEOS IN RECORD ##############
# processing  data\trainFS.tfrecord
# ############# 1202 VIDEOS IN RECORD ##############
# processing  data\trainHA.tfrecord
# ############# 1222 VIDEOS IN RECORD ##############
# processing  data\trainha.tfrecord
# ############# 1222 VIDEOS IN RECORD ##############
# processing  data\trainhI.tfrecord
# ############# 1198 VIDEOS IN RECORD ##############
# processing  data\trainhR.tfrecord
# ############# 1249 VIDEOS IN RECORD ##############
# processing  data\trainI0.tfrecord
# ############# 1224 VIDEOS IN RECORD ##############
# processing  data\trainI1.tfrecord
# ############# 1216 VIDEOS IN RECORD ##############
# processing  data\trainih.tfrecord
# ############# 1190 VIDEOS IN RECORD ##############
# processing  data\trainIJ.tfrecord
# ############# 1202 VIDEOS IN RECORD ##############
# processing  data\trainIU.tfrecord
# ############# 1172 VIDEOS IN RECORD ##############
# processing  data\trainjq.tfrecord
# ############# 1215 VIDEOS IN RECORD ##############
# processing  data\trainjw.tfrecord
# ############# 1183 VIDEOS IN RECORD ##############
# processing  data\trainK1.tfrecord
# ############# 1230 VIDEOS IN RECORD ##############
# processing  data\trainke.tfrecord
# ############# 1125 VIDEOS IN RECORD ##############
# processing  data\trainkr.tfrecord
# ############# 1193 VIDEOS IN RECORD ##############
# processing  data\trainkV.tfrecord
# ############# 1202 VIDEOS IN RECORD ##############
# processing  data\trainLC.tfrecord
# ############# 1160 VIDEOS IN RECORD ##############
# processing  data\trainlo.tfrecord
# ############# 1170 VIDEOS IN RECORD ##############
# processing  data\trainLq.tfrecord
# ############# 1186 VIDEOS IN RECORD ##############
# processing  data\trainmh.tfrecord
# ############# 1237 VIDEOS IN RECORD ##############
# processing  data\trainN9.tfrecord
# ############# 1261 VIDEOS IN RECORD ##############
# processing  data\trainny.tfrecord
# ############# 1158 VIDEOS IN RECORD ##############
# processing  data\trainog.tfrecord
# ############# 1194 VIDEOS IN RECORD ##############
# processing  data\trainOp.tfrecord
# ############# 1202 VIDEOS IN RECORD ##############
# processing  data\trainpd.tfrecord
# ############# 1159 VIDEOS IN RECORD ##############
# processing  data\trainpX.tfrecord
# ############# 1202 VIDEOS IN RECORD ##############
# processing  data\trainqf.tfrecord
# ############# 1198 VIDEOS IN RECORD ##############
# processing  data\trainQy.tfrecord
# ############# 1263 VIDEOS IN RECORD ##############
# processing  data\trainR4.tfrecord
# ############# 1200 VIDEOS IN RECORD ##############
# processing  data\trainr4.tfrecord
# ############# 1200 VIDEOS IN RECORD ##############
# processing  data\trainrH.tfrecord
# ############# 1191 VIDEOS IN RECORD ##############
# processing  data\trainRK.tfrecord
# ############# 1178 VIDEOS IN RECORD ##############
# processing  data\trainry.tfrecord
# ############# 1211 VIDEOS IN RECORD ##############
# processing  data\trainTb.tfrecord
# ############# 1228 VIDEOS IN RECORD ##############
# processing  data\trainTv.tfrecord
# ############# 1205 VIDEOS IN RECORD ##############
# processing  data\trainUS.tfrecord
# ############# 1194 VIDEOS IN RECORD ##############
# processing  data\trainUY.tfrecord
# ############# 1237 VIDEOS IN RECORD ##############
# processing  data\trainv5.tfrecord
# ############# 1189 VIDEOS IN RECORD ##############
# processing  data\trainvE.tfrecord
# ############# 1185 VIDEOS IN RECORD ##############
# processing  data\trainVi.tfrecord
# ############# 1227 VIDEOS IN RECORD ##############
# processing  data\trainVK.tfrecord
# ############# 1184 VIDEOS IN RECORD ##############
# processing  data\trainWK.tfrecord
# ############# 1278 VIDEOS IN RECORD ##############
# processing  data\trainw_.tfrecord
# ############# 1199 VIDEOS IN RECORD ##############
# processing  data\trainX2.tfrecord
# ############# 1214 VIDEOS IN RECORD ##############
# processing  data\trainX6.tfrecord
# ############# 1183 VIDEOS IN RECORD ##############
# processing  data\trainYi.tfrecord
# ############# 1223 VIDEOS IN RECORD ##############
# processing  data\trainZ6.tfrecord
# ############# 1224 VIDEOS IN RECORD ##############
# processing  data\trainzk.tfrecord
# ############# 1163 VIDEOS IN RECORD ##############
# processing  data\train_k.tfrecord
# ############# 1179 VIDEOS IN RECORD ##############
#
# Analyzed 95229 videos from YT8M

# %%
categories =  {122 : "Weight training",
               204 : "Gym",
               529 : "Squat",
               532 : "Barbell",
               892 : "Aerobics",
              898 : "Pilates",
               1389 : "Dumbell",
               1430 : "Pull Up",           
               2044 : "Bodyweight",
               2045 : "Bicep Curls",
               4441 : "Functional Training",
              4667 : "Golds Gym"}

# %%
# label 204 is gym
gymVids = set()
for val in featureDict:
    for cat in categories:
        if cat in featureDict[val]:
            print(val)
            gymVids.add(val)
# Out:
# 0_vuEHrDPgU
# 0_drNWXP03o
# 0_drNWXP03o
# 0_drNWXP03o
# 0_drNWXP03o
# 0_sMYmprk0c
# 0_RNf3_fS9Q
# 0_TC9Uux5nc
# 0_TC9Uux5nc
# 0_V1VOm1Ew4
# 0_KasQtLbI4
# 0_1sDeNUFOM
# 0_Swz1fzt6s
# 0_Swz1fzt6s
# 0_Swz1fzt6s
# 0_fSV0sjEUI
# 0_fSV0sjEUI
# 0_fSV0sjEUI
# 0_fSV0sjEUI
# 0_Ew-Hgr0DM
# 0_Ew-Hgr0DM
# 19GOIJZWDiY
# 19LuhC2W520
# 19LuhC2W520
# 19LuhC2W520
# 19Y2JpLYT2M
# 19Mk7gN2xJI
# 19Mk7gN2xJI
# 19budeaZYAc
# 19budeaZYAc
# 19budeaZYAc
# 45rYQy1wDUA
# 45rYQy1wDUA
# 4570SAsVEhw
# 45aM-3b5_FU
# 457Qop0JY3Y
# 45RzmBNYkq0
# 45RzmBNYkq0
# 45RzmBNYkq0
# 45RzmBNYkq0
# 45rJzAt1qUI
# 45DXz4Ou5oU
# 45U1YOtZ8bM
# 45RST1oktMY
# 45I-cZtsgno
# 45I-cZtsgno
# 45wf8GMx2OM
# 45vyIp8ruw0
# 4BJIDIqbzjk
# 4BInsLN9j8Y
# 4BlCFYBIjx0
# 4BlCFYBIjx0
# 4Bfq4mYD__Y
# 4BwUGUwor1U
# 4BKMVuszT8c
# 4B1ZLp6AMtA
# 4B1ZLp6AMtA
# 4BB5yy4kbPk
# 4fjMC6aCrCI
# 4fncDxDsEc8
# 4fncDxDsEc8
# 4fM-P2NveGU
# 4fM-P2NveGU
# 4fbKjbpKiF8
# 4fbKjbpKiF8
# 4fjuWOEwXQ4
# 4fjuWOEwXQ4
# 4fe30BjIi2Y
# 4f0ob4SOnd0
# 4fSIbYNETv4
# 4fSIbYNETv4
# 4VUR7XUhhLk
# 4VHG1o9DUSw
# 4VHG1o9DUSw
# 4VSQ-Bl0Hzc
# 5AtQi3i9ZzI
# 5Apub3s2B8U
# 5AWT69U_91k
# 5AWT69U_91k
# 5AWT69U_91k
# 5AWT69U_91k
# 5A_ks6oAXr0
# 5A7nlhuA8A0
# 5ASWCBm7WQA
# 5Ai6trT_6SI
# 5ri3tGdnoyI
# 5rTh2bahFhQ
# 5rTh2bahFhQ
# 5r1vWNBN1cg
# 5rvCJVFvJiU
# 5rvCJVFvJiU
# 5r8wSrdwnAI
# 5rO0SpGh2Lw
# 5rO0SpGh2Lw
# 5rO0SpGh2Lw
# 5rO0SpGh2Lw
# 5r2te_7cgG0
# 5r3XunVaiMw
# 5rd570tehrM
# 5rEFpm-PIPs
# 6ApiJylm-IY
# 6AyVI7VvBZQ
# 6AH4626KeME
# 6AgJ7QpKp7Y
# 6AgJ7QpKp7Y
# 6A9sropagUI
# 6Apw44_SE10
# 6Apw44_SE10
# 6AL26DaNIxs
# 6AL26DaNIxs
# 6AL26DaNIxs
# 6AL26DaNIxs
# 6AEDbzzFGsM
# 6AEDbzzFGsM
# 6AYrCQilIyc
# 6AvO2b8dCVk
# 6AvO2b8dCVk
# 6AvO2b8dCVk
# 6liMDPqkmqc
# 6liMDPqkmqc
# 6l681F1Cnks
# 6l681F1Cnks
# 6l681F1Cnks
# 6lQUKsn3XN8
# 6l5g7tJyzL0
# 6l5g7tJyzL0
# 6lR2nXWu1Eo
# 6lR2nXWu1Eo
# 6llKhCpjsDM
# 6llKhCpjsDM
# 6l4QDdfohpc
# 6lbA1qkEd5w
# 6yEJvwSCoh0
# 6yEJvwSCoh0
# 6yEJvwSCoh0
# 6y4FjYXjS7o
# 6yDSpgA7CdY
# 6yDSpgA7CdY
# 6ylXt5feAa8
# 6yOWmSSc-_s
# 6yOWmSSc-_s
# 6yOWmSSc-_s
# 6yOWmSSc-_s
# 6y5paEJbaMY
# 6yTeZIL86Fo
# 6yTeZIL86Fo
# 6yJIK30O4sg
# 7SRT7lOnbI8
# 7SogrLD3taM
# 7SqT4r97Ds0
# 7SrOrJhvOn8
# 7SrOrJhvOn8
# 7SSnzjmCVIM
# ogurwhUJo-w
# ogEki4Z2uCM
# ogEki4Z2uCM
# ogEki4Z2uCM
# ogEki4Z2uCM
# ogThVDeO0O4
# ogThVDeO0O4
# ogTjE7y84e4
# ogTjE7y84e4
# ogTjE7y84e4
# ogzwHlAwrX0
# ogzwHlAwrX0
# og0umWK3e7c
# Op1SNaAvJys
# Op1SNaAvJys
# OpxG2GOjEww
# OpjjYjOfEgA
# Op2SOGne2UU
# Op2SOGne2UU
# OpvTpc_nauI
# OpvTpc_nauI
# OpG2HnLgAMI
# OpqOeSi7ZeU
# pd9WBkPLymI
# pd9WBkPLymI
# pdn7UyoZ0Tc
# pdvi-2Y846M
# pdvi-2Y846M
# pdBtXZXlmMs
# pd-Rh_OuVo0
# pd-Rh_OuVo0
# pd-Rh_OuVo0
# pdQiG4fz5pg
# pdQiG4fz5pg
# pdQiG4fz5pg
# pdWZUPNEWJM
# pdWZUPNEWJM
# pXKF7c05G8k
# pXF1jF9zXEY
# pX5yN4MtUcU
# pX1IfrJ8WjU
# pX1IfrJ8WjU
# pX1IfrJ8WjU
# pX1IfrJ8WjU
# qfKsRtCbyzs
# qfL9NNO-Opc
# qfL9NNO-Opc
# qfXyvlS7mPo
# Qy82-qTOB0c
# Qy_jaFqxCQ4
# Qy_jaFqxCQ4
# Qy-nR85S_YY
# Qy-nR85S_YY
# Qy-nR85S_YY
# Qy6FUoqSd9w
# Qy_sM4VhQiM
# Qywfw21lIG8
# QyYKziB6NOo
# QyKYEKrYraI
# R4KgKmsJ-eE
# R4KgKmsJ-eE
# R4KgKmsJ-eE
# R4KgKmsJ-eE
# R4L61fgB1FM
# R4L61fgB1FM
# R4L61fgB1FM
# R4be4uTW2pU
# R4be4uTW2pU
# R4be4uTW2pU
# R4be4uTW2pU
# R4thy4AWRhM
# R4YTHK3DhmI
# R4udKv6SP7U
# rH8iN7tnwnM
# rHchx9GuJ9E
# rHvDrRJ9I2g
# rHvDrRJ9I2g
# rHWSX-DHlKU
# rHmtVO7uTfo
# rHhSuL3TWxo
# rHtzU_-yxhU
# rHDQzaERNTM
# RKdpPmVl7sY
# RKL76kDbS5g
# RKuIHXz5lfY
# RKuIHXz5lfY
# RKuIHXz5lfY
# RKuIHXz5lfY
# RKpUzV-AbUg
# RKpUzV-AbUg
# RKpUzV-AbUg
# RKKloZ9RhaI
# RKKloZ9RhaI
# ryvm9Vaoqoo
# ryZx-y-HIGA
# ryZx-y-HIGA
# ryJEd9ETvvA
# ryJEd9ETvvA
# ryJEd9ETvvA
# ryJEd9ETvvA
# ry-TjwDuUVE
# ry-TjwDuUVE
# Tbd_q2ZMVD8
# Tbd_q2ZMVD8
# Tb4IPx5K-z0
# Tb4IPx5K-z0
# Tb4IPx5K-z0
# TbI4_OCSCkI
# TbI4_OCSCkI
# TbJkn4WP7wc
# Tb6Tjil6lHs
# TbMASa-9GqE
# Tb8j1ZfhNa4
# Tv87jvtwDy0
# TvkS-yAtm9g
# TvhDrccysfY
# TvhDrccysfY
# Tv_JxaAqD40
# TvFlYKJdX3Y
# TvRYK4wZuvM
# TvRYK4wZuvM
# USJ-gurIdlM
# USJ-gurIdlM
# USiqSj-rUmw
# US1HJVm8ADU
# US2qPm_QiV0
# USj5rc4XP7o
# USj5rc4XP7o
# USLRvSDL7Gc
# USbP4oBEHJs
# USIvoCHKJ1Q
# USIUVN1N8Wg
# USIUVN1N8Wg
# USIUVN1N8Wg
# USyak8ugBDA
# USX6ijVoWbM
# USX6ijVoWbM
# USChyifRgjM
# USChyifRgjM
# USPBqDYdHBc
# USPBqDYdHBc
# USPBqDYdHBc
# USHHkFouYFw
# USHHkFouYFw
# USoe7G0dWSQ
# USwonizmlFs
# USwonizmlFs
# USwonizmlFs
# USwonizmlFs
# UYsTQsoCjkM
# UYsTQsoCjkM
# UYJMinNrB7E
# UYJMinNrB7E
# UY36dbRT8cE
# UYJsaagO9Bs
# UYJsaagO9Bs
# UYO0bHwGzZk
# v5czDpIVcnY
# v5czDpIVcnY
# v5czDpIVcnY
# v5bABa8CkK4
# v5bABa8CkK4
# v5bABa8CkK4
# v5bABa8CkK4
# v55i98vzypM
# vENRfjXxU2o
# vENRfjXxU2o
# vE3yPhU73eY
# vE9PpJfNdc4
# vEj1XRW0a6A
# vEj1XRW0a6A
# vEj1XRW0a6A
# vEW8d-HtX_U
# vEW8d-HtX_U
# vEyItIavKjI
# vERcj78uvrs
# vERcj78uvrs
# vEfhEtq4AE4
# vEfhEtq4AE4
# vEna10tCMzM
# vEna10tCMzM
# ViufCQmKlAQ
# ViDKrK0YssE
# ViDKrK0YssE
# ViW_qVEIvWc
# ViSFl0zBa-Q
# ViMEuB-Uc70
# Vi9zt_aoc_c
# ViytXAobZ8Q
# ViytXAobZ8Q
# VilALqwz3pE
# VK33wObn4OA
# VKweFePVKFM
# VKweFePVKFM
# VKweFePVKFM
# VKweFePVKFM
# VK7RtfD3-bU
# VK7RtfD3-bU
# VKyKwQ9VTtw
# VKDTB1F-jRw
# VKDTB1F-jRw
# VKu13_0pVIg
# VKk0wnAXInc
# VKaEWZqefhw
# VKhH6ocAE1w
# VK1g3jISn5c
# VKgEdLl9yzE
# VKy5HBJYK_o
# VKy5HBJYK_o
# VKy5HBJYK_o
# VKhmRI8zp_o
# WKA_SA0BSvw
# WKA_SA0BSvw
# WKEFIiDGM7o
# WKJuZhYdIjg
# WK6mKYiZHgI
# WKJnTXhw81U
# WKJnTXhw81U
# WKqC6OUqQR8
# w_JXPPWbc8Q
# w_JXPPWbc8Q
# w_JXPPWbc8Q
# w_ExvRW3-sM
# w_BJTLQ1bH0
# w_BJTLQ1bH0
# w_BJTLQ1bH0
# w_BJTLQ1bH0
# w_yl6vr4928
# w_bxw5oxB20
# w_Tw-064OmE
# X2hLNDkLCmE
# X2hLNDkLCmE
# X2hLNDkLCmE
# X2hLNDkLCmE
# X28Jp_xwSJo
# X2iDr_mfftk
# X2iDr_mfftk
# X2Y6ynX5T2o
# X2yJoVyZ6hk
# X2yJoVyZ6hk
# X2yJoVyZ6hk
# X2yx2G_y6JA
# X2yx2G_y6JA
# X2yx2G_y6JA
# X2yx2G_y6JA
# X2MzHtYMey8
# X2MzHtYMey8
# X6EcBIeibGQ
# X6EcBIeibGQ
# X6d7dfKnWMg
# X6d7dfKnWMg
# X6Q7fZ-6RT0
# X6cuNQ23dJI
# X6cuNQ23dJI
# X6cuNQ23dJI
# X6fCxSJw_OM
# X6pRVz0PoIM
# X6D-XiB7F5k
# X6b9iroSZEc
# X6m2fZwOXa4
# X6Ot5WlFe7Y
# X6nHBwt428A
# YinzEVCjg2Q
# Yi7DJjstKtY
# YikXf4P35TI
# YiIkXk5XeGU
# YiIkXk5XeGU
# YilkVQrkozg
# YilkVQrkozg
# YilkVQrkozg
# YikXZkubNJY
# YikXZkubNJY
# YikXZkubNJY
# Yibk83qx49c
# Yibk83qx49c
# Yibk83qx49c
# Yibk83qx49c
# Z6oWj_anAdI
# Z6gnD7v2c0A
# Z60Y8wTcDUA
# Z60Y8wTcDUA
# Z60Y8wTcDUA
# Z60Y8wTcDUA
# Z6-MJpHDgb4
# Z6-MJpHDgb4
# Z6-MJpHDgb4
# Z6-MJpHDgb4
# Z6-MJpHDgb4
# Z6IL3cSkU9I
# Z6uiYbyr6ek
# Z6uiYbyr6ek
# Z6JJ-McXTLI
# Z6yCsnnD5SA
# Z6yCsnnD5SA
# Z6yCsnnD5SA
# Z6yCsnnD5SA
# Z6Un0gm4IXw
# Z6gA4DOqc1w
# Z6gA4DOqc1w
# Z6BBXRji5j0
# Z6BBXRji5j0
# zkamULFmN8M
# zkamULFmN8M
# zkamULFmN8M
# zkQ6Pf6a_7k
# zkQ6Pf6a_7k
# zkZYQ2kAxvA
# zknAHddaUnM
# zkqwAqzSjfY
# zk8pqJfLr6Q
# _km0Xs8lSko
# _km0Xs8lSko
# _kjVCoojn6c
# _kRmZnKYChw
# _kRmZnKYChw
# _kRmZnKYChw
# _kLc5kztUf0
# _k-ZxRpYh3M
# _k-ZxRpYh3M
# _k-ZxRpYh3M
# _k-ZxRpYh3M
# _k_ycG6MdWU
# _k_ycG6MdWU
# _kH5bObjSow
# _kH5bObjSow
# _kJuLmO4edg
# _kJuLmO4edg

# %%
print(len(gymVids))
# Out:
# 555

# %%
from IPython.display import YouTubeVideo
gymVids = list(gymVids)

# %%
# this worked on my local jupyter notebook, but doesn't show on gith
YouTubeVideo(gymVids[0])

# %%
https://www.googleapis.com/youtube/v3/videos?part=snippet&i=oDOXeO9fAg4&key==AIzaSyCrFWiPfGcb5IsyS-wpAMk6eaNdMaC8pXs

# %%
import csv
api_key = 'AIzaSyCrFWiPfGcb5IsyS-wpAMk6eaNdMaC8pXs'
channel = 'UCF0pVplsI8R5kcAqgtoRqoA'
vidStats =  'https://www.googleapis.com/youtube/v3/videos?part=id,statistics&id='
vidSnips = 'https://www.googleapis.com/youtube/v3/videos?part=id,snippet&id='

with open('videoStats.csv', 'a') as c:

    writer = csv.writer(c)

    writer.writerow(['Id', 
                     'Title', 
                     'Description', 
                     'LikeCount', 
                     'DislikeCount', 
                     'ViewCount', 
                     'FavoriteCount', 
                     'CommentCount', 
                     'PublishedAt', 
                     'Channel Id', 
                     'Channel Title',
                     'Audio Language',
                     'Tags',
                    'Thumbnail Default',
                   'All Thumbnails'])


for vid in gymVids:
    stats = json.load(urllib2.urlopen(vidStats + vid[0] + '&key=' + api_key))
    snips = json.load(urllib2.urlopen(vidSnips + vid[0] + '&key=' + api_key))
    if(len(stats['items'])==0):
        continue
    s = stats['items'][0]['statistics']
    sn = snips['items'][0]
    writer.writerow([sn['id'], 
                     sn['snippet']['title'].encode('utf8'), 
                     sn['snippet']['description'].encode('utf8'), 
                     s['likeCount'],
                     s['dislikeCount'], 
                     s['viewCount'], 
                     s['favoriteCount'], 
                     s['commentCount'], 
                     sn['snippet']['publishedAt'],
                     sn['snippet']['channelId'],
                     sn['snippet']['channelTitle'],
                     sn['snippet']['defaultAudioLanguage'],
                     sn['snippet']['tags'],
                     sn['snippet']['thumbnails']['default'],
                     sn['snippet']['thumbnails']])
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-76-3fd4d1b52e23> in <module>()
#       5 vidSnips = 'https://www.googleapis.com/youtube/v3/videos?part=id,snippet&id='
#       6
# ----> 7 with open('videoStats.csv', 'a') as c:
#       8
#       9     writer = csv.writer(c)
#
# PermissionError: [Errno 13] Permission denied: 'videoStats.csv'

# %%
stats = json.load(urllib2.urlopen(vidStats + vid[0] + '&key=' + api_key))

# %%
print(len(stats['items']))
# Out:
# 0

# %%
import urllib.request as urllib2
from lxml import html, etree
import json

stats = json.load(urllib2.urlopen('https://www.googleapis.com/youtube/v3/videos?part=statistics&id=ugWrhUwOqJo&key=AIzaSyCrFWiPfGcb5IsyS-wpAMk6eaNdMaC8pXs'))

# %%
snips = json.load(urllib2.urlopen('https://www.googleapis.com/youtube/v3/videos?part=snippet&id=ugWrhUwOqJo&key=AIzaSyCrFWiPfGcb5IsyS-wpAMk6eaNdMaC8pXs'))

# %%
print(stats)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/tuoYv7qujzILyFDW2cBF69I_IpE"', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}, 'items': [{'kind': 'youtube#video', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/EXeg0J2lZFD6d7zdLh3zjroGwpo"', 'id': 'ugWrhUwOqJo', 'statistics': {'viewCount': '172983', 'likeCount': '5348', 'dislikeCount': '232', 'favoriteCount': '0', 'commentCount': '462'}}]}

# %%
print(snips)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/X2gfjk2wqp87QOSt62b7GWvUHtY"', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}, 'items': [{'kind': 'youtube#video', 'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/PWOA9AuCpPdqg7yLSgZ2UH_Loao"', 'id': 'ugWrhUwOqJo', 'snippet': {'publishedAt': '2017-10-15T15:33:15.000Z', 'channelId': 'UCU1iJ2ChGwaNLvBjip0p2Ag', 'title': 'Exposing Our Weakness!! Featuring Sergi Constance', 'description': '➢ Sergi\'s instagram: https://www.instagram.com/sergiconstance/?hl=en\n➢shop alphalete: http://www.alphaleteathletics.com\n➢ www.mvmtwatches.com 15% code "cgfitness15" http://tinyurl.com/julte73\n➢ ghost: http://tinyurl.com/gpxc69v discount "cguzman"\n➢ UP Energy: http://www.shopupenergy.com\n➢ Bite Meals: http://www.bitemeals.com/idevaffiliate/idevaffiliate.php?id=cgfit use code "CGUZMAN"\n➢ online coaching: http://christianguzman.com\n➢ snapchat: guzmanfitness\n➢ umoro shaker: http://www.umoro.com/\n➢ alphalete gym: I would love for you to check out the Alphalete Gym! We currently offer full memberships, as well as day- and week-passes. All packages, mail, or anything else you may wish to send to me is best directed to: \n\n711 Avenue E\nStafford, TX\n77477', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ugWrhUwOqJo/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/ugWrhUwOqJo/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/ugWrhUwOqJo/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/ugWrhUwOqJo/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/ugWrhUwOqJo/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'Christian Guzman', 'tags': ['CHRISTIAN', 'GUZMAN', 'ALPHALETE', 'VLOG', 'RELATIONSHIP', 'LIFESTYLE', 'LAMBORGHINI', 'SUPERCAR', 'BUSINESS', 'ENTREPRENEUR', 'BUFFBUNNY', 'COUPLE', 'GOALS', 'PRANK', 'FRIENDLY', 'GIRLFRIEND', 'HAPPY', 'VIRAL'], 'categoryId': '22', 'liveBroadcastContent': 'none', 'localized': {'title': 'Exposing Our Weakness!! Featuring Sergi Constance', 'description': '➢ Sergi\'s instagram: https://www.instagram.com/sergiconstance/?hl=en\n➢shop alphalete: http://www.alphaleteathletics.com\n➢ www.mvmtwatches.com 15% code "cgfitness15" http://tinyurl.com/julte73\n➢ ghost: http://tinyurl.com/gpxc69v discount "cguzman"\n➢ UP Energy: http://www.shopupenergy.com\n➢ Bite Meals: http://www.bitemeals.com/idevaffiliate/idevaffiliate.php?id=cgfit use code "CGUZMAN"\n➢ online coaching: http://christianguzman.com\n➢ snapchat: guzmanfitness\n➢ umoro shaker: http://www.umoro.com/\n➢ alphalete gym: I would love for you to check out the Alphalete Gym! We currently offer full memberships, as well as day- and week-passes. All packages, mail, or anything else you may wish to send to me is best directed to: \n\n711 Avenue E\nStafford, TX\n77477'}, 'defaultAudioLanguage': 'en'}}]}

# %%
s = stats['items'][0]['statistics']

# %%
print(s)
# Out:
# {'viewCount': '172983', 'likeCount': '5348', 'dislikeCount': '232', 'favoriteCount': '0', 'commentCount': '462'}

# %%
s = stats['items'][0]['snippet']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-1802bb819ab1> in <module>()
# ----> 1 s = stats['items'][0]['snippet']
#
# KeyError: 'snippet'

# %%
sn = snips['items'][0]

# %%
print(sn['snippet']['tags'])
# Out:
# ['CHRISTIAN', 'GUZMAN', 'ALPHALETE', 'VLOG', 'RELATIONSHIP', 'LIFESTYLE', 'LAMBORGHINI', 'SUPERCAR', 'BUSINESS', 'ENTREPRENEUR', 'BUFFBUNNY', 'COUPLE', 'GOALS', 'PRANK', 'FRIENDLY', 'GIRLFRIEND', 'HAPPY', 'VIRAL']
